# %%
from scipy.io import wavfile
import librosa
import IPython.display as ipd
import pyaudio
from matplotlib import pyplot as plt

# %% [markdown]
# # Techniques to Import

# %%
file_name= "input.wav"

# %%
# using scipy

sample_rate=22050

wav_data={}
sample_rate,wav_data['scipy']=wavfile.read(file_name)
wav_data['librosa'],sample_rate=librosa.load(file_name)

# %%
plt.plot(wav_data['scipy'][:1000])
plt.show()
plt.plot(wav_data['librosa'][:1000])
plt.show()

# %% [markdown]
# # Export

# %%
ipd.display(ipd.Audio('input.wav'))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
