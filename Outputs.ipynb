# %%
import IPython.display as ipd

# %% [markdown]
# # Audio Synthesis

# %%
audio_github = "samples/audio_synthesis_github.wav"

audio_self = "samples/audio_synthesis_self.wav"

speech_tacotron_1 = "samples/tacotron_1_self.wav"

speech_tacotron_2_statistic = "samples/tacotron_2_statistical.wav"

speech_tacotron_2_neural = "samples/tacotron_2_wavenet_self.wav"

# %% [markdown]
# ### Audio Synthesis   (WaveRNN)

# %% [markdown]
# #### From Open Source

# %%
ipd.display(ipd.Audio(audio_github))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### Self Trained Model

# %%
ipd.display(ipd.Audio(audio_self))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Speech Synthesis

# %% [markdown]
# ### Tacotron - 1 (statistical synthesis)

# %%
ipd.display(ipd.Audio(speech_tacotron_1))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Tacotron - 2 (Statistical synthesis)

# %%
ipd.display(ipd.Audio(speech_tacotron_2_statistic))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Tacotron - 2 (Neural Synthesis)

# %%
ipd.display(ipd.Audio(speech_tacotron_2_neural))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
