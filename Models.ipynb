# %% [markdown]
# # Current Models

# %%
from IPython.display import Image

# %% [markdown]
# ## Tacotron - 1

# %%
Image("data/tacotron-1.png")

# %% [markdown]
# ## Tacotron - 2

# %%
Image("data/tacotron-2.png")

# %% [markdown]
# ## WaveRNN

# %%
Image("data/wavernn.png")
